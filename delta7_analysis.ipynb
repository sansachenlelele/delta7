# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_rows', None)

import bokeh
import hvplot.pandas
import holoviews as hv

import bokeh.palettes
from bokeh.plotting import figure, show, output_notebook

import neuprint

import importlib
import lib as cl
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='e123eb9f-639b-4dd2-8bca-63eae676752a'>
#   <div id="f00557bd-8333-48cc-8353-7af5023d72c0" data-root-id="e123eb9f-639b-4dd2-8bca-63eae676752a" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
TOKEN = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJlbWFpbCI6Imt5bGllaHVjaEBiZXJrZWxleS5lZHUiLCJsZXZlbCI6Im5vYXV0aCIsImltYWdlLXVybCI6Imh0dHBzOi8vbGgzLmdvb2dsZXVzZXJjb250ZW50LmNvbS9hL0FDZzhvY0tpVkJGeHFzT1JxRlhnNnNOX0xIWnd4RjRoWDJORWh4WFBpY2hDaEV1Qjdsei0yUT1zOTYtYz9zej01MD9zej01MCIsImV4cCI6MTkyMjI1NDAyMH0.WLushXPCMuxMHltv_LUpoVmhtGyZSTZw08ShIrEboLY"

c = neuprint.Client('neuprint.janelia.org', 'hemibrain:v1.2.1', TOKEN)

# %%
importlib.reload(cl)
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='9b33b2f2-c964-410d-96d6-1394ddb42a82'>
#   <div id="d1b98f1f-d922-484c-963b-2643bbcb8b7e" data-root-id="9b33b2f2-c964-410d-96d6-1394ddb42a82" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
d7_ns, roi_cnts = neuprint.fetch_neurons(neuprint.NeuronCriteria(type='Delta7'))
d7_subtypes = d7_ns['instance'].unique()
print(d7_subtypes)
# Out:
# ['Delta7(PB15)_L6R3_L' 'Delta7(PB15)_L5R4_L' 'Delta7(PB15)_L4R5_R'
#  'Delta7(PB15)_L1L9R8_R' 'Delta7(PB15)_L8R1R9_L' 'Delta7(PB15)_L4R6_R'
#  'Delta7(PB15)_L3R6_R' 'Delta7(PB15)_L7R2_L' 'Delta7(PB15)_L6R4_L'
#  'Delta7(PB15)_L2R7_R' 'Delta7(PB15)_L7R3_L']

# %%
d7_l6r3_l, _ = neuprint.fetch_neurons(neuprint.NeuronCriteria(instance='Delta7(PB15)_L6R3_L'))
d7_l6r3_l_bids = d7_l6r3_l['bodyId'].unique()
print(len(d7_l6r3_l))
print(len(d7_l6r3_l_bids))
# Out:
# 5
# 5

# %% [markdown]
# ## Delta7(PB15)_L6R3_L intra-subtype connections

# %%
d7_l6r3_l_conn = cl.fetch_connectivity(target_scale='instance', conn_scale='instance', conn_type='post', target_id='Delta7(PB15)_L6R3_L', conn_id='Delta7(PB15)_L6R3_L', rois=['PB'])

print(d7_l6r3_l_conn)
# Out:
#     bodyId_pre  bodyId_post roi  weight type_pre         instance_pre  \
# 0    734581598    911919044  PB      33   Delta7  Delta7(PB15)_L6R3_L
# 19   973959177    941814787  PB      27   Delta7  Delta7(PB15)_L6R3_L
# 15   941814787    973959177  PB      24   Delta7  Delta7(PB15)_L6R3_L
# 4    911919044    734581598  PB      22   Delta7  Delta7(PB15)_L6R3_L
# 17   973959177    911919044  PB      20   Delta7  Delta7(PB15)_L6R3_L
# 11   941482720    973959177  PB      19   Delta7  Delta7(PB15)_L6R3_L
# 2    734581598    941814787  PB      18   Delta7  Delta7(PB15)_L6R3_L
# 12   941814787    734581598  PB      18   Delta7  Delta7(PB15)_L6R3_L
# 9    941482720    911919044  PB      18   Delta7  Delta7(PB15)_L6R3_L
# 5    911919044    941482720  PB      18   Delta7  Delta7(PB15)_L6R3_L
# 18   973959177    941482720  PB      15   Delta7  Delta7(PB15)_L6R3_L
# 3    734581598    973959177  PB      15   Delta7  Delta7(PB15)_L6R3_L
# ...

# %%
cl.visualize_conn(d7_l6r3_l_conn, pre_scale='neuron', post_scale='neuron', sort_by='bodyId', weight_col='weight', height=500, width=700, x_ax_rot=60)
# Out:
# :HeatMap   [columns,index]   (value)

# %% [markdown]
# ## Delta7(PB15)_L5R4_L intra-subtype connections

# %%
d7_l5r4_l_conn = cl.fetch_connectivity(target_scale='instance', conn_scale='instance', conn_type='post', target_id='Delta7(PB15)_L5R4_L', conn_id='Delta7(PB15)_L5R4_L', rois=['PB'])

cl.visualize_conn(d7_l5r4_l_conn, pre_scale='neuron', post_scale='neuron', sort_by='bodyId', weight_col='weight', height=500, width=700, x_ax_rot=60)
# Out:
# :HeatMap   [columns,index]   (value)

# %% [markdown]
# ## Delta7(PB15)_L4R5_R

# %%
d7_l4r5_r_conn = cl.fetch_connectivity(target_scale='instance', conn_scale='instance', conn_type='post', target_id='Delta7(PB15)_L4R5_R', conn_id='Delta7(PB15)_L4R5_R', rois=['PB'])

cl.visualize_conn(d7_l4r5_r_conn, pre_scale='neuron', post_scale='neuron', sort_by='bodyId', weight_col='weight', height=500, width=700, x_ax_rot=60)
# Out:
# :HeatMap   [columns,index]   (value)

# %% [markdown]
# ## Delta7(PB15)_L1L9R8_R

# %%
d7_l1l9r8_r_conn = cl.fetch_connectivity(target_scale='instance', conn_scale='instance', conn_type='post', target_id='Delta7(PB15)_L1L9R8_R', conn_id='Delta7(PB15)_L1L9R8_R', rois=['PB'])

cl.visualize_conn(d7_l1l9r8_r_conn, pre_scale='neuron', post_scale='neuron', sort_by='bodyId', weight_col='weight', height=500, width=700, x_ax_rot=60)
# Out:
# :HeatMap   [columns,index]   (value)

# %% [markdown]
# ## Delta7(PB15)_L8R1R9_L

# %%
d7_l8r1r9_l_conn = cl.fetch_connectivity(target_scale='instance', conn_scale='instance', conn_type='post', target_id='Delta7(PB15)_L8R1R9_L', conn_id='Delta7(PB15)_L8R1R9_L', rois=['PB'])

cl.visualize_conn(d7_l8r1r9_l_conn, pre_scale='neuron', post_scale='neuron', sort_by='bodyId', weight_col='weight', height=500, width=700, x_ax_rot=60)
# Out:
# :HeatMap   [columns,index]   (value)

# %% [markdown]
# ## Delta7(PB15)_L4R6_R

# %%
d7_l4r6_r_conn = cl.fetch_connectivity(target_scale='instance', conn_scale='instance', conn_type='post', target_id='Delta7(PB15)_L4R6_R', conn_id='Delta7(PB15)_L4R6_R', rois=['PB'])

cl.visualize_conn(d7_l4r6_r_conn, pre_scale='neuron', post_scale='neuron', sort_by='bodyId', weight_col='weight', height=500, width=700, x_ax_rot=60)
# Out:
# :HeatMap   [columns,index]   (value)

# %% [markdown]
# ## Delta7(PB15)_L3R6_R

# %%
d7_l3r6_r_conn = cl.fetch_connectivity(target_scale='instance', conn_scale='instance', conn_type='post', target_id='Delta7(PB15)_L3R6_R', conn_id='Delta7(PB15)_L3R6_R', rois=['PB'])

cl.visualize_conn(d7_l3r6_r_conn, pre_scale='neuron', post_scale='neuron', sort_by='bodyId', weight_col='weight', height=500, width=700, x_ax_rot=60)
# Out:
# :HeatMap   [columns,index]   (value)

# %% [markdown]
# ## Delta7(PB15)_L7R2_L

# %%
d7_l7r2_l_conn = cl.fetch_connectivity(target_scale='instance', conn_scale='instance', conn_type='post', target_id='Delta7(PB15)_L7R2_L', conn_id='Delta7(PB15)_L7R2_L', rois=['PB'])

cl.visualize_conn(d7_l7r2_l_conn, pre_scale='neuron', post_scale='neuron', sort_by='bodyId', weight_col='weight', height=500, width=700, x_ax_rot=60)
# Out:
# :HeatMap   [columns,index]   (value)

# %% [markdown]
# ## Delta7(PB15)_L6R4_L

# %%
d7_l6r4_l_conn = cl.fetch_connectivity(target_scale='instance', conn_scale='instance', conn_type='post', target_id='Delta7(PB15)_L6R4_L', conn_id='Delta7(PB15)_L6R4_L', rois=['PB'])

cl.visualize_conn(d7_l6r4_l_conn, pre_scale='neuron', post_scale='neuron', sort_by='bodyId', weight_col='weight', height=500, width=700, x_ax_rot=60)
# Out:
# :HeatMap   [columns,index]   (value)

# %% [markdown]
# ## Delta7(PB15)_L2R7_R

# %%
d7_l2r7_r_conn = cl.fetch_connectivity(target_scale='instance', conn_scale='instance', conn_type='post', target_id='Delta7(PB15)_L2R7_R', conn_id='Delta7(PB15)_L2R7_R', rois=['PB'])

cl.visualize_conn(d7_l2r7_r_conn, pre_scale='neuron', post_scale='neuron', sort_by='bodyId', weight_col='weight', height=500, width=700, x_ax_rot=60)
# Out:
# :HeatMap   [columns,index]   (value)

# %% [markdown]
# ## Delta7(PB15)_L7R3_L

# %%
nc = neuprint.NeuronCriteria(instance='Delta7(PB15)_L7R3_L')
d7_l7r3_l, _ = neuprint.fetch_neurons(nc)
print(len(d7_l7r3_l))
# Out:
# 1

# %%
d7_l7r3_l_n, d7_l7r3_l_conns = neuprint.fetch_adjacencies(nc, nc, rois=None, min_roi_weight=1, include_nonprimary=False)
print(d7_l7r3_l_conns)
# Out:
# Empty DataFrame
# Columns: [bodyId_pre, bodyId_post, roi, weight]
# Index: []

# %%
d7_l7r3_l_conn = cl.fetch_connectivity(target_scale='instance', conn_scale='instance', conn_type='post', target_id='Delta7(PB15)_L7R3_L', conn_id='Delta7(PB15)_L7R3_L', rois=['PB'])

cl.visualize_conn(d7_l7r3_l_conn, pre_scale='neuron', post_scale='neuron', sort_by='bodyId', weight_col='weight', height=500, width=700, x_ax_rot=60)
# Out:
# :HeatMap   [columns,index]   (value)

# %% [markdown]
# ## ∆7 neighbor connection plots

# %%
conn = cl.fetch_connectivity(target_scale='instance', conn_scale='instance', conn_type='post', target_id='Delta7(PB15)_L6R3_L', conn_id='Delta7(PB15)_L5R4_L', rois=['PB'])

cl.visualize_conn(conn, pre_scale='neuron', post_scale='neuron', sort_by='bodyId', weight_col='weight', height=500, width=700, x_ax_rot=60)
# Out:
# :HeatMap   [columns,index]   (value)

# %%
conn = cl.fetch_connectivity(target_scale='instance', conn_scale='instance', conn_type='post', conn_id='Delta7(PB15)_L6R3_L', target_id='Delta7(PB15)_L5R4_L', rois=['PB'])

cl.visualize_conn(conn, pre_scale='neuron', post_scale='neuron', sort_by='bodyId', weight_col='weight', height=500, width=700, x_ax_rot=60)
# Out:
# :HeatMap   [columns,index]   (value)

# %% [markdown]
# ## ∆7 population connectivity plots

# %%
conn = cl.fetch_connectivity(target_scale='type', conn_scale='type', conn_type='post', conn_id='Delta7', target_id='Delta7', rois=['PB'])

cl.visualize_conn(conn, pre_scale='neuron', post_scale='neuron', sort_by='instance', weight_col='weight', height=700, width=800, x_ax_rot=60)
# Out:
# :HeatMap   [columns,index]   (value)

# %%
cl.visualize_conn(conn, pre_scale='instance', post_scale='instance', sort_by='instance', weight_col='weight', height=700, width=800, x_ax_rot=60)
# Out:
# :HeatMap   [columns,index]   (value)
