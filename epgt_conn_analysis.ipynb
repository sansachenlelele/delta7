# %% [markdown]
# # Notebook for analyzing EPGt connectivity

# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_rows', None)

import bokeh
import hvplot.pandas
import holoviews as hv

import bokeh.palettes
from bokeh.plotting import figure, show, output_notebook

import neuprint

import importlib
import lib as cl

TOKEN = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJlbWFpbCI6Imt5bGllaHVjaEBiZXJrZWxleS5lZHUiLCJsZXZlbCI6Im5vYXV0aCIsImltYWdlLXVybCI6Imh0dHBzOi8vbGgzLmdvb2dsZXVzZXJjb250ZW50LmNvbS9hL0FDZzhvY0tpVkJGeHFzT1JxRlhnNnNOX0xIWnd4RjRoWDJORWh4WFBpY2hDaEV1Qjdsei0yUT1zOTYtYz9zej01MD9zej01MCIsImV4cCI6MTkyMjI1NDAyMH0.WLushXPCMuxMHltv_LUpoVmhtGyZSTZw08ShIrEboLY"

c = neuprint.Client('neuprint.janelia.org', 'hemibrain:v1.2.1', TOKEN)
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='715590a4-3d63-48ea-9644-d464584a0459'>
#   <div id="a07af744-92c9-40c6-9f97-5028ff9a3627" data-root-id="715590a4-3d63-48ea-9644-d464584a0459" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"675a9fb1-5ad7-4cc6-8c2e-deb3d6c66501":{"version":"3.6.3","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"715590a4-3d63-48ea-9644-d464584a0459"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"85bb478b-cdda-405b-bbc2-46d60fb1e788","attributes":{"plot_id":"715590a4-3d63-48ea-9644-d464584a0459","comm_id":"455bf2293e78478193b673dab055f40c","client_comm_id":"e2100b2e36ce48238f7c2b5a12e95987"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_rendered","kind":"Any","default":false},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","d ...
#   var render_items = [{"docid":"675a9fb1-5ad7-4cc6-8c2e-deb3d6c66501","roots":{"715590a4-3d63-48ea-9644-d464584a0459":"a07af744-92c9-40c6-9f97-5028ff9a3627"},"root_ids":["715590a4-3d63-48ea-9644-d464584a0459"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>

# %%
importlib.reload(cl)
from lib import syn_specs
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='9d1f6c68-ea6f-4152-bad1-1db1458bf377'>
#   <div id="edc14a92-3c28-4e8a-a87e-c55a53306da6" data-root-id="9d1f6c68-ea6f-4152-bad1-1db1458bf377" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"9cf0454b-1007-495e-8dd6-a2f30df00149":{"version":"3.6.3","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"9d1f6c68-ea6f-4152-bad1-1db1458bf377"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"342c1dea-ba35-4519-87a2-20fcfa457be6","attributes":{"plot_id":"9d1f6c68-ea6f-4152-bad1-1db1458bf377","comm_id":"8c4c39eb6a824edd9ce178cd87fc0f20","client_comm_id":"3ef87f7985224e0d833bcc9bc1b7aef8"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_rendered","kind":"Any","default":false},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","d ...
#   var render_items = [{"docid":"9cf0454b-1007-495e-8dd6-a2f30df00149","roots":{"9d1f6c68-ea6f-4152-bad1-1db1458bf377":"edc14a92-3c28-4e8a-a87e-c55a53306da6"},"root_ids":["9d1f6c68-ea6f-4152-bad1-1db1458bf377"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>

# %% [markdown]
# ## EPGt subtype classes and neuron instances

# %%
epgt_nc = neuprint.NeuronCriteria(type='EPGt')
epgts, _ = neuprint.fetch_neurons(epgt_nc)
epgt_subtypes = epgts['instance'].unique()
epgt_subtype_insts = {inst : list(epgts[epgts['instance']==inst]['bodyId']) for inst in epgt_subtypes}

for k,v in epgt_subtype_insts.items():
    print(k,v)
# Out:
# EPGt(PB09)_R9 [1168659995, 1219069439]
# EPGt(PB09)_L9 [1168660239, 1168664447]

# %% [markdown]
# ## Direct Inputs

# %%
epgt_tot_pre_conn = cl.fetch_connectivity(target_scale='type', conn_scale='all', conn_type='pre', target_id='EPGt', rois=['EB', 'PB'])
print(epgt_tot_pre_conn)
# Out:
#      bodyId_pre              instance_pre     type_pre  bodyId_post  \
# 51    911911193     Delta7(PB15)_L8R1R9_L       Delta7   1219069439
# 50    911911193     Delta7(PB15)_L8R1R9_L       Delta7   1168659995
# 36    910783883     Delta7(PB15)_L8R1R9_L       Delta7   1168659995
# 53    911919917     Delta7(PB15)_L1L9R8_R       Delta7   1168664447
# 28    881221166     Delta7(PB15)_L1L9R8_R       Delta7   1168664447
# 48    911911004     Delta7(PB15)_L1L9R8_R       Delta7   1168660239
# 37    910783883     Delta7(PB15)_L8R1R9_L       Delta7   1219069439
# 32    910442752     Delta7(PB15)_L8R1R9_L       Delta7   1219069439
# 52    911919917     Delta7(PB15)_L1L9R8_R       Delta7   1168660239
# 46    911578595     Delta7(PB15)_L8R1R9_L       Delta7   1219069439
# 42    911574261     Delta7(PB15)_L1L9R8_R       Delta7   1168660239
# 25    881217171              LPsP(PB13)_R         LPsP   1219069439
# 81   1095275456              LPsP(PB13)_L         LPsP   1219069439
# 62    972513129            P6-8P9(PB14)_R       P6-8P9   1219069439
# 44    911578595     Delta7(PB15)_L8R1R9_L       Delta7   1168659995
# 291  5813061383     Delta7(PB15)_L1L9R8_R       Delta7   1168664447
# 27    881221166     Delta7(PB15)_L1L9R8_R       Delta7   1168660239
# 43    911574261     Delta7(PB15)_L1L9R8_R       Delta7   1168664447
# 35    910783731     Delta7(PB15)_L8R1R9_L       Delta7   1219069439
# 34    910783731     Delta7(PB15)_L8R1R9_L       Delta7   1168659995
# 285  5813058389            P6-8P9(PB14)_R       P6-8P9   1219069439
# 49    911911004     Delta7(PB15)_L1L9R8_R       Delta7   1168664447
# 61    972513129            P6-8P9(PB14)_R       P6-8P9   1168659995
# 22    881217171              LPsP(PB13)_R         LPsP   1168659995
# 80   1095275456              LPsP(PB13)_L         LPsP   1168664447
# 290  5813061383     Delta7(PB15)_L1L9R8_R       Delta7   1168660239
# 23    881217171              LPsP(PB13)_R         LPsP   1168660239
# 71   1004018344            P6-8P9(PB14)_L       P6-8P9   1168664447
# 79   1095275456              LPsP(PB13)_L         LPsP   1168660239
# 78   1095275456              LPsP(PB13)_L         LPsP   1168659995
# 70   1004018344            P6-8P9(PB14)_L       P6-8P9   1168660239
# 128  1220239654                      None         None   1168660239
# 24    881217171              LPsP(PB13)_R         LPsP   1168664447
# 129  1220239654                      None         None   1168664447
# 280  5813047157           PEN_b(PB06b)_L2  PEN_b(PEN2)   1219069439
# 59    941469301              P1-9(PB19)_R         P1-9   1168659995
# 278  5813047157           PEN_b(PB06b)_L2  PEN_b(PEN2)   1168659995
# 284  5813058389            P6-8P9(PB14)_R       P6-8P9   1168659995
# 9     634608104           PEN_a(PB06a)_L2  PEN_a(PEN1)   1219069439
# 12    724280817           PEN_b(PB06b)_R2  PEN_b(PEN2)   1168660239
# 39    911565408              P1-9(PB19)_L         P1-9   1168660239
# 279  5813047157           PEN_b(PB06b)_L2  PEN_b(PEN2)   1168660239
# 132  1228692168              ExR6(ring)_L         ExR6   1168659995
# 14    724280817           PEN_b(PB06b)_R2  PEN_b(PEN2)   1219069439
# 66    972892437           PEN_a(PB06a)_R2  PEN_a(PEN1)   1219069439
# 134  1228692168              ExR6(ring)_L         ExR6   1168664447
# 63    972892437           PEN_a(PB06a)_R2  PEN_a(PEN1)   1168659995
# 40    911565408              P1-9(PB19)_L         P1-9   1168664447
# 16    858587718              ExR6(ring)_R         ExR6   1168659995
# 6     634608104           PEN_a(PB06a)_L2  PEN_a(PEN1)   1168659995
# 17    858587718              ExR6(ring)_R         ExR6   1168660239
# 26    881221166     Delta7(PB15)_L1L9R8_R       Delta7   1168659995
# 108  1188388754           IbSpsP(PB17)_R9       IbSpsP   1219069439
# 60    941469301              P1-9(PB19)_R         P1-9   1219069439
# 64    972892437           PEN_a(PB06a)_R2  PEN_a(PEN1)   1168660239
# 8     634608104           PEN_a(PB06a)_L2  PEN_a(PEN1)   1168664447
# 7     634608104           PEN_a(PB06a)_L2  PEN_a(PEN1)   1168660239
# 56    941136727              SpsP(PB16)_R         SpsP   1219069439
# 245  1447576662              EPG(PB08)_L1          EPG   1168659995
# 133  1228692168              ExR6(ring)_L         ExR6   1168660239
# 88   1125969082              PEG(PB07)_R9          PEG   1219069439
# 86   1125969082              PEG(PB07)_R9          PEG   1168659995
# 123  1218732640           PEN_a(PB06a)_R9  PEN_a(PEN1)   1168659995
# 269  5813020585            ER3p_a(ring)_R       ER3p_a   1168659995
# 58    941469110              SpsP(PB16)_R         SpsP   1219069439
# 144  1260327246            ER3p_b(ring)_R       ER3p_b   1168664447
# 19    858587718              ExR6(ring)_R         ExR6   1219069439
# 31    910442752     Delta7(PB15)_L8R1R9_L       Delta7   1168659995
# 293  5813069339           IbSpsP(PB17)_L9       IbSpsP   1168660239
# 65    972892437           PEN_a(PB06a)_R2  PEN_a(PEN1)   1168664447
# 99   1168340507                 EL(EQ5)_L           EL   1168664447
# 172  1294082002             ER1_b(ring)_R        ER1_b   1219069439
# 13    724280817           PEN_b(PB06b)_R2  PEN_b(PEN2)   1168664447
# 298  5813087532           IbSpsP(PB17)_R9       IbSpsP   1219069439
# 295  5813077544              EPG(PB08)_R1          EPG   1168660239
# 294  5813069339           IbSpsP(PB17)_L9       IbSpsP   1168664447
# 297  5813087532           IbSpsP(PB17)_R9       IbSpsP   1168659995
# 296  5813077544              EPG(PB08)_R1          EPG   1168664447
# 2     570461892           PEN_a(PB06a)_R3  PEN_a(PEN1)   1168660239
# 21    881212361              SpsP(PB16)_L         SpsP   1168660239
# 247  1508334312           PEN_a(PB06a)_L3  PEN_a(PEN1)   1168659995
# 161  1291435776            ER3p_a(ring)_R       ER3p_a   1168659995
# 151  1291094620             ER1_b(ring)_R        ER1_b   1168664447
# 131  1220576923           PEN_a(PB06a)_L9  PEN_a(PEN1)   1168664447
# 120  1199677638              PEG(PB07)_L9          PEG   1168664447
# 170  1294082002             ER1_b(ring)_R        ER1_b   1168659995
# 159  1291435551             ER1_a(ring)_R        ER1_a   1219069439
# 57    941469110              SpsP(PB16)_R         SpsP   1168659995
# 55    941136727              SpsP(PB16)_R         SpsP   1168659995
# 286  5813059835             ER1_a(ring)_L        ER1_a   1168659995
# 216  1322470594            ER3p_a(ring)_L       ER3p_a   1168659995
# 226  1322811240            ER3p_a(ring)_R       ER3p_a   1168659995
# 265  5813020568            ER3p_a(ring)_R       ER3p_a   1168659995
# 197  1322133858             ER1_a(ring)_R        ER1_a   1219069439
# 176  1322129437             ER1_a(ring)_L        ER1_a   1219069439
# 169  1292882359                 EL(EQ5)_R           EL   1219069439
# 196  1322133858             ER1_a(ring)_R        ER1_a   1168660239
# 205  1322466938             ER1_a(ring)_R        ER1_a   1168660239
# 223  1322811128            ER3p_b(ring)_L       ER3p_b   1168664447
# 29    881221166     Delta7(PB15)_L1L9R8_R       Delta7   1219069439
# 18    858587718              ExR6(ring)_R         ExR6   1168664447
# 213  1322470509            ER3p_a(ring)_L       ER3p_a   1168659995
# 166  1292882359                 EL(EQ5)_R           EL   1168659995
# 155  1291103485             ER1_a(ring)_L        ER1_a   1168660239
# 150  1261169514            ER3p_a(ring)_L       ER3p_a   1219069439
# 5     572870540              EPG(PB08)_L1          EPG   1219069439
# 262  5813014873              EPG(PB08)_R1          EPG   1168664447
# 289  5813061383     Delta7(PB15)_L1L9R8_R       Delta7   1168659995
# 107  1188388754           IbSpsP(PB17)_R9       IbSpsP   1168659995
# 148  1260828727            ER3p_a(ring)_L       ER3p_a   1219069439
# 147  1260828727            ER3p_a(ring)_L       ER3p_a   1168664447
# 135  1228692168              ExR6(ring)_L         ExR6   1219069439
# 87   1125969082              PEG(PB07)_R9          PEG   1168659995
# 266  5813020568            ER3p_a(ring)_R       ER3p_a   1168660239
# 82   1095279301         IbSpsP(PB17)_R7/9       IbSpsP   1168659995
# 275  5813040233              EPG(PB08)_R8          EPG   1168659995
# 263  5813014873              EPG(PB08)_R1          EPG   1219069439
# 194  1322133825             ER1_a(ring)_L        ER1_a   1219069439
# 76   1066088381                 EL(EQ5)_L           EL   1168664447
# 143  1260327246            ER3p_b(ring)_R       ER3p_b   1168659995
# 219  1322474586            ER3p_a(ring)_R       ER3p_a   1168659995
# 225  1322811232            ER3p_b(ring)_L       ER3p_b   1168664447
# 204  1322466938             ER1_a(ring)_R        ER1_a   1168659995
# 220  1322474586            ER3p_a(ring)_R       ER3p_a   1168660239
# 221  1322474586            ER3p_a(ring)_R       ER3p_a   1219069439
# 241  1355806197             ER1_a(ring)_R        ER1_a   1219069439
# 250  1600079770          PFNv(PB05)_L9_C9         PFNv   1168660239
# 238  1353168228             ER1_b(ring)_L        ER1_b   1219069439
# 243  1447253749                 EL(EQ5)_R           EL   1168659995
# 0     483245369                    FB1G_L         FB1G   1168659995
# 251  1600083889           PEN_b(PB06b)_L9  PEN_b(PEN2)   1168660239
# 253  1730608428              ExR4(ring)_R         ExR4   1168659995
# 256  5812979459            ER3p_a(ring)_L       ER3p_a   1168659995
# 268  5813020568            ER3p_a(ring)_R       ER3p_a   1219069439
# 270  5813020585            ER3p_a(ring)_R       ER3p_a   1168660239
# 272  5813027016            FB4Y(EB/NO1)_R         FB4Y   1219069439
# 274  5813038224            ER3w_a(ring)_L       ER3w_a   1168664447
# 276  5813041180    FB4L(PPM3-FB3/4-DAN)_R         FB4L   1168664447
# 235  1352823209             ER1_a(ring)_L        ER1_a   1219069439
# 236  1353168228             ER1_b(ring)_L        ER1_b   1168659995
# 246  1449247522  ExR2(PPM3-EB-DAN/ring)_R         ExR2   1219069439
# 281  5813053983            ER3w_b(ring)_R       ER3w_b   1168659995
# 69   1002507159              EPG(PB08)_R7          EPG   1168659995
# 227  1322811240            ER3p_a(ring)_R       ER3p_a   1168660239
# 228  1322811240            ER3p_a(ring)_R       ER3p_a   1168664447
# 45    911578595     Delta7(PB15)_L8R1R9_L       Delta7   1168660239
# 47    911893174              SpsP(PB16)_L         SpsP   1168660239
# 105  1168660239             EPGt(PB09)_L9         EPGt   1168664447
# 113  1198330641              ExR4(ring)_L         ExR4   1219069439
# 211  1322470462             ER1_a(ring)_R        ER1_a   1168660239
# 217  1322470594            ER3p_a(ring)_L       ER3p_a   1168664447
# 218  1322470594            ER3p_a(ring)_L       ER3p_a   1219069439
# 200  1322137688             ER1_b(ring)_R        ER1_b   1219069439
# 202  1322138079             ER1_b(ring)_R        ER1_b   1219069439
# 206  1322466938             ER1_a(ring)_R        ER1_a   1168664447
# 115  1199086313            ER3p_a(ring)_L       ER3p_a   1168660239
# 116  1199086313            ER3p_a(ring)_L       ER3p_a   1168664447
# 118  1199677638              PEG(PB07)_L9          PEG   1168660239
# 96   1167995070              EPG(PB08)_L8          EPG   1168664447
# 100  1168340507                 EL(EQ5)_L           EL   1219069439
# 94   1136865339  ExR2(PPM3-EB-DAN/ring)_L         ExR2   1168664447
# 72   1005308608                 EL(EQ5)_L           EL   1168659995
# 73   1005308608                 EL(EQ5)_L           EL   1219069439
# 74   1043825714              ExR5(ring)_R         ExR5   1168659995
# 126  1218732931          PFNd(PB04)_R9_C1         PFNd   1168659995
# 130  1220576923           PEN_a(PB06a)_L9  PEN_a(PEN1)   1168660239
# 136  1229288307            ER3p_a(ring)_R       ER3p_a   1168659995
# 137  1229288307            ER3p_a(ring)_R       ER3p_a   1168660239
# 138  1229288307            ER3p_a(ring)_R       ER3p_a   1219069439
# 139  1229369776             ER2_b(ring)_R        ER2_b   1168659995
# 186  1322133296             ER1_a(ring)_L        ER1_a   1168660239
# 187  1322133296             ER1_a(ring)_L        ER1_a   1168664447
# 190  1322133768             ER1_a(ring)_L        ER1_a   1168659995
# 191  1322133768             ER1_a(ring)_L        ER1_a   1219069439
# 192  1322133825             ER1_a(ring)_L        ER1_a   1168660239
# 145  1260327246            ER3p_b(ring)_R       ER3p_b   1219069439
# 146  1260400286            ER3w_a(ring)_R       ER3w_a   1168664447
# 149  1261169514            ER3p_a(ring)_L       ER3p_a   1168659995
# 178  1322129610             ER1_b(ring)_R        ER1_b   1219069439
# 179  1322129724             ER1_b(ring)_L        ER1_b   1219069439
# 183  1322129781             ER1_a(ring)_R        ER1_a   1168664447
# 154  1291103485             ER1_a(ring)_L        ER1_a   1168659995
# 158  1291435551             ER1_a(ring)_R        ER1_a   1168664447
# 160  1291435693             ER1_b(ring)_R        ER1_b   1219069439
# 164  1291444314             ER1_a(ring)_L        ER1_a   1168664447
# 165  1291444314             ER1_a(ring)_L        ER1_a   1219069439
# 168  1292882359                 EL(EQ5)_R           EL   1168664447
# 173  1294414279             ER1_a(ring)_R        ER1_a   1219069439
# 174  1322129437             ER1_a(ring)_L        ER1_a   1168660239
# 258  5812979459            ER3p_a(ring)_L       ER3p_a   1219069439
# 259  5812987803          PFNv(PB05)_R9_C1         PFNv   1168659995
# 4     572870540              EPG(PB08)_L1          EPG   1168659995
# 3     570461892           PEN_a(PB06a)_R3  PEN_a(PEN1)   1168664447
# 11    724280817           PEN_b(PB06b)_R2  PEN_b(PEN2)   1168659995
# 10    695629525              EPG(PB08)_R2          EPG   1168664447
# 103  1168392468            ER3w_b(ring)_L       ER3w_b   1168664447
# 104  1168659995             EPGt(PB09)_R9         EPGt   1219069439
# 237  1353168228             ER1_b(ring)_L        ER1_b   1168664447
# 239  1355806197             ER1_a(ring)_R        ER1_a   1168659995
# 240  1355806197             ER1_a(ring)_R        ER1_a   1168660239
# 242  1386577828                      None         None   1168660239
# 244  1447253749                 EL(EQ5)_R           EL   1219069439
# 271  5813020585            ER3p_a(ring)_R       ER3p_a   1219069439
# 261  5813014873              EPG(PB08)_R1          EPG   1168660239
# 1     513784136                    FB1G_R         FB1G   1168659995
# 167  1292882359                 EL(EQ5)_R           EL   1168660239
# 171  1294082002             ER1_b(ring)_R        ER1_b   1168664447
# 175  1322129437             ER1_a(ring)_L        ER1_a   1168664447
# 177  1322129610             ER1_b(ring)_R        ER1_b   1168660239
# 156  1291103485             ER1_a(ring)_L        ER1_a   1168664447
# 157  1291103485             ER1_a(ring)_L        ER1_a   1219069439
# 162  1291444314             ER1_a(ring)_L        ER1_a   1168659995
# 163  1291444314             ER1_a(ring)_L        ER1_a   1168660239
# 180  1322129730             ER1_b(ring)_L        ER1_b   1168664447
# 181  1322129781             ER1_a(ring)_R        ER1_a   1168659995
# 182  1322129781             ER1_a(ring)_R        ER1_a   1168660239
# 184  1322129781             ER1_a(ring)_R        ER1_a   1219069439
# 185  1322133296             ER1_a(ring)_L        ER1_a   1168659995
# 140  1230121634            ER3w_a(ring)_L       ER3w_a   1168659995
# 141  1230125720            ER3w_b(ring)_L       ER3w_b   1168664447
# 142  1230324385            ER3w_b(ring)_R       ER3w_b   1168660239
# 152  1291094620             ER1_b(ring)_R        ER1_b   1219069439
# 153  1291094742             ER1_b(ring)_L        ER1_b   1168664447
# 188  1322133296             ER1_a(ring)_L        ER1_a   1219069439
# 189  1322133531             ER1_b(ring)_L        ER1_b   1168659995
# 193  1322133825             ER1_a(ring)_L        ER1_a   1168664447
# 125  1218732781          PFNd(PB04)_R9_C1         PFNd   1219069439
# 127  1219069439             EPGt(PB09)_R9         EPGt   1168659995
# 195  1322133858             ER1_a(ring)_R        ER1_a   1168659995
# 198  1322137688             ER1_b(ring)_R        ER1_b   1168659995
# 75   1043825714              ExR5(ring)_R         ExR5   1219069439
# 77   1066088381                 EL(EQ5)_L           EL   1219069439
# 83   1095279301         IbSpsP(PB17)_R7/9       IbSpsP   1219069439
# 84   1100792636            FB4Y(EB/NO1)_L         FB4Y   1219069439
# 85   1125964814              EPG(PB08)_R8          EPG   1219069439
# 89   1127476096              EPG(PB08)_L8          EPG   1168664447
# 90   1128088594              PEG(PB07)_L1          PEG   1168660239
# 91   1136204852          PFGs(PB10)_R9_C1         PFGs   1168659995
# 92   1136204852          PFGs(PB10)_R9_C1         PFGs   1219069439
# 93   1136865339  ExR2(PPM3-EB-DAN/ring)_L         ExR2   1168660239
# 95   1155652503          PFNa(PB03)_R9_C1         PFNa   1219069439
# 97   1168055653            ER3w_b(ring)_L       ER3w_b   1219069439
# 98   1168340507                 EL(EQ5)_L           EL   1168660239
# 101  1168392003            ER3w_b(ring)_L       ER3w_b   1168659995
# 102  1168392468            ER3w_b(ring)_L       ER3w_b   1168660239
# 199  1322137688             ER1_b(ring)_R        ER1_b   1168660239
# 117  1199431561            ER3w_a(ring)_L       ER3w_a   1168659995
# 119  1199677638              PEG(PB07)_L9          PEG   1168660239
# 121  1199677638              PEG(PB07)_L9          PEG   1168664447
# 122  1218728541          PFNa(PB03)_R9_C1         PFNa   1219069439
# 124  1218732640           PEN_a(PB06a)_R9  PEN_a(PEN1)   1219069439
# 201  1322138079             ER1_b(ring)_R        ER1_b   1168664447
# 203  1322142804             ER1_b(ring)_L        ER1_b   1168659995
# 207  1322470368             ER1_a(ring)_R        ER1_a   1168660239
# 208  1322470368             ER1_a(ring)_R        ER1_a   1168664447
# 209  1322470368             ER1_a(ring)_R        ER1_a   1219069439
# 210  1322470462             ER1_a(ring)_R        ER1_a   1168659995
# 212  1322470462             ER1_a(ring)_R        ER1_a   1219069439
# 214  1322470509            ER3p_a(ring)_L       ER3p_a   1168660239
# 215  1322470509            ER3p_a(ring)_L       ER3p_a   1168664447
# 222  1322811128            ER3p_b(ring)_L       ER3p_b   1168659995
# 106  1168664447             EPGt(PB09)_L9         EPGt   1168660239
# 109  1189891402          PFGs(PB10)_L8_C8         PFGs   1168660239
# 110  1198330286  ExR2(PPM3-EB-DAN/ring)_R         ExR2   1168660239
# 111  1198330641              ExR4(ring)_L         ExR4   1168659995
# 112  1198330641              ExR4(ring)_L         ExR4   1168664447
# 114  1199086313            ER3p_a(ring)_L       ER3p_a   1168659995
# 224  1322811232            ER3p_b(ring)_L       ER3p_b   1168659995
# 229  1322811240            ER3p_a(ring)_R       ER3p_a   1219069439
# 230  1323156554            ER3p_b(ring)_R       ER3p_b   1168659995
# 41    911574261     Delta7(PB15)_L1L9R8_R       Delta7   1168659995
# 54    912545106              EPG(PB08)_L2          EPG   1168659995
# 67    973566036           PEN_b(PB06b)_R3  PEN_b(PEN2)   1168660239
# 68    978733459              ExR5(ring)_L         ExR5   1219069439
# 231  1324209745                FB3B(EB)_L         FB3B   1168664447
# 232  1352823209             ER1_a(ring)_L        ER1_a   1168659995
# 233  1352823209             ER1_a(ring)_L        ER1_a   1168660239
# 234  1352823209             ER1_a(ring)_L        ER1_a   1168664447
# 282  5813056953           PEN_a(PB06a)_R4  PEN_a(PEN1)   1168664447
# 283  5813057963                FB3B(EB)_R         FB3B   1168664447
# 287  5813059835             ER1_a(ring)_L        ER1_a   1219069439
# 288  5813060726              ExR5(ring)_R         ExR5   1219069439
# 292  5813061383     Delta7(PB15)_L1L9R8_R       Delta7   1219069439
# 273  5813038224            ER3w_a(ring)_L       ER3w_a   1168659995
# 277  5813045050            ER3w_b(ring)_L       ER3w_b   1168659995
# 248  1508369047                 EL(EQ5)_R           EL   1168664447
# 249  1509029359                      None         None   1168660239
# 252  1600083889           PEN_b(PB06b)_L9  PEN_b(PEN2)   1168660239
# 254  1730608428              ExR4(ring)_R         ExR4   1219069439
# 255  5812979230            ER3w_b(ring)_R       ER3w_b   1168659995
# 15    757055317           PEN_a(PB06a)_L4  PEN_a(PEN1)   1219069439
# 20    880530613       Delta7(PB15)_L5R4_L       Delta7   1168660239
# 30    910442723       Delta7(PB15)_L4R5_R       Delta7   1219069439
# 33    910442782       Delta7(PB15)_L4R6_R       Delta7   1219069439
# 38    911129339       Delta7(PB15)_L4R5_R       Delta7   1168659995
# 264  5813020455            ER3w_b(ring)_R       ER3w_b   1168659995
# 267  5813020568            ER3p_a(ring)_R       ER3p_a   1168664447
# 257  5812979459            ER3p_a(ring)_L       ER3p_a   1168664447
# 260  5812987803          PFNv(PB05)_R9_C1         PFNv   1219069439
#
#      instance_post type_post roi  weight
# 51   EPGt(PB09)_R9      EPGt  PB      88
# 50   EPGt(PB09)_R9      EPGt  PB      85
# 36   EPGt(PB09)_R9      EPGt  PB      82
# 53   EPGt(PB09)_L9      EPGt  PB      76
# 28   EPGt(PB09)_L9      EPGt  PB      65
# 48   EPGt(PB09)_L9      EPGt  PB      64
# 37   EPGt(PB09)_R9      EPGt  PB      57
# 32   EPGt(PB09)_R9      EPGt  PB      54
# 52   EPGt(PB09)_L9      EPGt  PB      53
# 46   EPGt(PB09)_R9      EPGt  PB      53
# 42   EPGt(PB09)_L9      EPGt  PB      48
# 25   EPGt(PB09)_R9      EPGt  PB      47
# 81   EPGt(PB09)_R9      EPGt  PB      45
# 62   EPGt(PB09)_R9      EPGt  PB      43
# 44   EPGt(PB09)_R9      EPGt  PB      43
# 291  EPGt(PB09)_L9      EPGt  PB      41
# 27   EPGt(PB09)_L9      EPGt  PB      41
# 43   EPGt(PB09)_L9      EPGt  PB      38
# 35   EPGt(PB09)_R9      EPGt  PB      37
# 34   EPGt(PB09)_R9      EPGt  PB      37
# 285  EPGt(PB09)_R9      EPGt  PB      37
# 49   EPGt(PB09)_L9      EPGt  PB      36
# 61   EPGt(PB09)_R9      EPGt  PB      31
# 22   EPGt(PB09)_R9      EPGt  PB      31
# 80   EPGt(PB09)_L9      EPGt  PB      30
# 290  EPGt(PB09)_L9      EPGt  PB      29
# 23   EPGt(PB09)_L9      EPGt  PB      28
# 71   EPGt(PB09)_L9      EPGt  PB      27
# 79   EPGt(PB09)_L9      EPGt  PB      26
# 78   EPGt(PB09)_R9      EPGt  PB      26
# 70   EPGt(PB09)_L9      EPGt  PB      25
# 128  EPGt(PB09)_L9      EPGt  PB      24
# 24   EPGt(PB09)_L9      EPGt  PB      24
# 129  EPGt(PB09)_L9      EPGt  PB      20
# 280  EPGt(PB09)_R9      EPGt  EB      19
# 59   EPGt(PB09)_R9      EPGt  PB      17
# 278  EPGt(PB09)_R9      EPGt  EB      16
# 284  EPGt(PB09)_R9      EPGt  PB      14
# 9    EPGt(PB09)_R9      EPGt  EB      13
# 12   EPGt(PB09)_L9      EPGt  EB      12
# 39   EPGt(PB09)_L9      EPGt  PB      12
# 279  EPGt(PB09)_L9      EPGt  EB      12
# 132  EPGt(PB09)_R9      EPGt  EB      11
# 14   EPGt(PB09)_R9      EPGt  EB      11
# 66   EPGt(PB09)_R9      EPGt  EB       9
# 134  EPGt(PB09)_L9      EPGt  EB       9
# 63   EPGt(PB09)_R9      EPGt  EB       9
# 40   EPGt(PB09)_L9      EPGt  PB       8
# 16   EPGt(PB09)_R9      EPGt  EB       8
# 6    EPGt(PB09)_R9      EPGt  EB       8
# 17   EPGt(PB09)_L9      EPGt  EB       7
# 26   EPGt(PB09)_R9      EPGt  PB       7
# 108  EPGt(PB09)_R9      EPGt  PB       7
# 60   EPGt(PB09)_R9      EPGt  PB       7
# 64   EPGt(PB09)_L9      EPGt  EB       7
# 8    EPGt(PB09)_L9      EPGt  EB       7
# 7    EPGt(PB09)_L9      EPGt  EB       7
# 56   EPGt(PB09)_R9      EPGt  PB       7
# 245  EPGt(PB09)_R9      EPGt  EB       6
# 133  EPGt(PB09)_L9      EPGt  EB       6
# 88   EPGt(PB09)_R9      EPGt  PB       6
# 86   EPGt(PB09)_R9      EPGt  PB       6
# 123  EPGt(PB09)_R9      EPGt  EB       6
# 269  EPGt(PB09)_R9      EPGt  EB       6
# 58   EPGt(PB09)_R9      EPGt  PB       6
# 144  EPGt(PB09)_L9      EPGt  EB       5
# 19   EPGt(PB09)_R9      EPGt  EB       5
# 31   EPGt(PB09)_R9      EPGt  PB       5
# 293  EPGt(PB09)_L9      EPGt  PB       5
# 65   EPGt(PB09)_L9      EPGt  EB       5
# 99   EPGt(PB09)_L9      EPGt  EB       5
# 172  EPGt(PB09)_R9      EPGt  EB       5
# 13   EPGt(PB09)_L9      EPGt  EB       5
# 298  EPGt(PB09)_R9      EPGt  PB       5
# 295  EPGt(PB09)_L9      EPGt  EB       5
# 294  EPGt(PB09)_L9      EPGt  PB       5
# 297  EPGt(PB09)_R9      EPGt  PB       4
# 296  EPGt(PB09)_L9      EPGt  EB       4
# 2    EPGt(PB09)_L9      EPGt  EB       4
# 21   EPGt(PB09)_L9      EPGt  PB       4
# 247  EPGt(PB09)_R9      EPGt  EB       4
# 161  EPGt(PB09)_R9      EPGt  EB       4
# 151  EPGt(PB09)_L9      EPGt  EB       4
# 131  EPGt(PB09)_L9      EPGt  EB       4
# 120  EPGt(PB09)_L9      EPGt  PB       4
# 170  EPGt(PB09)_R9      EPGt  EB       4
# 159  EPGt(PB09)_R9      EPGt  EB       4
# 57   EPGt(PB09)_R9      EPGt  PB       4
# 55   EPGt(PB09)_R9      EPGt  PB       4
# 286  EPGt(PB09)_R9      EPGt  EB       4
# 216  EPGt(PB09)_R9      EPGt  EB       4
# 226  EPGt(PB09)_R9      EPGt  EB       4
# 265  EPGt(PB09)_R9      EPGt  EB       4
# 197  EPGt(PB09)_R9      EPGt  EB       4
# 176  EPGt(PB09)_R9      EPGt  EB       4
# 169  EPGt(PB09)_R9      EPGt  EB       4
# 196  EPGt(PB09)_L9      EPGt  EB       4
# 205  EPGt(PB09)_L9      EPGt  EB       4
# 223  EPGt(PB09)_L9      EPGt  EB       4
# 29   EPGt(PB09)_R9      EPGt  PB       4
# 18   EPGt(PB09)_L9      EPGt  EB       4
# 213  EPGt(PB09)_R9      EPGt  EB       4
# 166  EPGt(PB09)_R9      EPGt  EB       3
# 155  EPGt(PB09)_L9      EPGt  EB       3
# 150  EPGt(PB09)_R9      EPGt  EB       3
# 5    EPGt(PB09)_R9      EPGt  EB       3
# 262  EPGt(PB09)_L9      EPGt  EB       3
# 289  EPGt(PB09)_R9      EPGt  PB       3
# 107  EPGt(PB09)_R9      EPGt  PB       3
# 148  EPGt(PB09)_R9      EPGt  EB       3
# 147  EPGt(PB09)_L9      EPGt  EB       3
# 135  EPGt(PB09)_R9      EPGt  EB       3
# 87   EPGt(PB09)_R9      EPGt  EB       3
# 266  EPGt(PB09)_L9      EPGt  EB       3
# 82   EPGt(PB09)_R9      EPGt  PB       3
# 275  EPGt(PB09)_R9      EPGt  EB       3
# 263  EPGt(PB09)_R9      EPGt  EB       3
# 194  EPGt(PB09)_R9      EPGt  EB       3
# 76   EPGt(PB09)_L9      EPGt  EB       3
# 143  EPGt(PB09)_R9      EPGt  EB       3
# 219  EPGt(PB09)_R9      EPGt  EB       3
# 225  EPGt(PB09)_L9      EPGt  EB       3
# 204  EPGt(PB09)_R9      EPGt  EB       3
# 220  EPGt(PB09)_L9      EPGt  EB       3
# 221  EPGt(PB09)_R9      EPGt  EB       3
# 241  EPGt(PB09)_R9      EPGt  EB       3
# 250  EPGt(PB09)_L9      EPGt  PB       3
# 238  EPGt(PB09)_R9      EPGt  EB       3
# 243  EPGt(PB09)_R9      EPGt  EB       3
# 0    EPGt(PB09)_R9      EPGt  EB       2
# 251  EPGt(PB09)_L9      EPGt  EB       2
# 253  EPGt(PB09)_R9      EPGt  EB       2
# 256  EPGt(PB09)_R9      EPGt  EB       2
# 268  EPGt(PB09)_R9      EPGt  EB       2
# 270  EPGt(PB09)_L9      EPGt  EB       2
# 272  EPGt(PB09)_R9      EPGt  EB       2
# 274  EPGt(PB09)_L9      EPGt  EB       2
# 276  EPGt(PB09)_L9      EPGt  EB       2
# 235  EPGt(PB09)_R9      EPGt  EB       2
# 236  EPGt(PB09)_R9      EPGt  EB       2
# 246  EPGt(PB09)_R9      EPGt  EB       2
# 281  EPGt(PB09)_R9      EPGt  EB       2
# 69   EPGt(PB09)_R9      EPGt  EB       2
# 227  EPGt(PB09)_L9      EPGt  EB       2
# 228  EPGt(PB09)_L9      EPGt  EB       2
# 45   EPGt(PB09)_L9      EPGt  PB       2
# 47   EPGt(PB09)_L9      EPGt  PB       2
# 105  EPGt(PB09)_L9      EPGt  PB       2
# 113  EPGt(PB09)_R9      EPGt  EB       2
# 211  EPGt(PB09)_L9      EPGt  EB       2
# 217  EPGt(PB09)_L9      EPGt  EB       2
# 218  EPGt(PB09)_R9      EPGt  EB       2
# 200  EPGt(PB09)_R9      EPGt  EB       2
# 202  EPGt(PB09)_R9      EPGt  EB       2
# 206  EPGt(PB09)_L9      EPGt  EB       2
# 115  EPGt(PB09)_L9      EPGt  EB       2
# 116  EPGt(PB09)_L9      EPGt  EB       2
# 118  EPGt(PB09)_L9      EPGt  PB       2
# 96   EPGt(PB09)_L9      EPGt  EB       2
# 100  EPGt(PB09)_R9      EPGt  EB       2
# 94   EPGt(PB09)_L9      EPGt  EB       2
# 72   EPGt(PB09)_R9      EPGt  EB       2
# 73   EPGt(PB09)_R9      EPGt  EB       2
# 74   EPGt(PB09)_R9      EPGt  EB       2
# 126  EPGt(PB09)_R9      EPGt  PB       2
# 130  EPGt(PB09)_L9      EPGt  EB       2
# 136  EPGt(PB09)_R9      EPGt  EB       2
# 137  EPGt(PB09)_L9      EPGt  EB       2
# 138  EPGt(PB09)_R9      EPGt  EB       2
# 139  EPGt(PB09)_R9      EPGt  EB       2
# 186  EPGt(PB09)_L9      EPGt  EB       2
# 187  EPGt(PB09)_L9      EPGt  EB       2
# 190  EPGt(PB09)_R9      EPGt  EB       2
# 191  EPGt(PB09)_R9      EPGt  EB       2
# 192  EPGt(PB09)_L9      EPGt  EB       2
# 145  EPGt(PB09)_R9      EPGt  EB       2
# 146  EPGt(PB09)_L9      EPGt  EB       2
# 149  EPGt(PB09)_R9      EPGt  EB       2
# 178  EPGt(PB09)_R9      EPGt  EB       2
# 179  EPGt(PB09)_R9      EPGt  EB       2
# 183  EPGt(PB09)_L9      EPGt  EB       2
# 154  EPGt(PB09)_R9      EPGt  EB       2
# 158  EPGt(PB09)_L9      EPGt  EB       2
# 160  EPGt(PB09)_R9      EPGt  EB       2
# 164  EPGt(PB09)_L9      EPGt  EB       2
# 165  EPGt(PB09)_R9      EPGt  EB       2
# 168  EPGt(PB09)_L9      EPGt  EB       2
# 173  EPGt(PB09)_R9      EPGt  EB       2
# 174  EPGt(PB09)_L9      EPGt  EB       2
# 258  EPGt(PB09)_R9      EPGt  EB       2
# 259  EPGt(PB09)_R9      EPGt  PB       2
# 4    EPGt(PB09)_R9      EPGt  EB       2
# 3    EPGt(PB09)_L9      EPGt  EB       2
# 11   EPGt(PB09)_R9      EPGt  EB       2
# 10   EPGt(PB09)_L9      EPGt  EB       1
# 103  EPGt(PB09)_L9      EPGt  EB       1
# 104  EPGt(PB09)_R9      EPGt  PB       1
# 237  EPGt(PB09)_L9      EPGt  EB       1
# 239  EPGt(PB09)_R9      EPGt  EB       1
# 240  EPGt(PB09)_L9      EPGt  EB       1
# 242  EPGt(PB09)_L9      EPGt  EB       1
# 244  EPGt(PB09)_R9      EPGt  EB       1
# 271  EPGt(PB09)_R9      EPGt  EB       1
# 261  EPGt(PB09)_L9      EPGt  EB       1
# 1    EPGt(PB09)_R9      EPGt  EB       1
# 167  EPGt(PB09)_L9      EPGt  EB       1
# 171  EPGt(PB09)_L9      EPGt  EB       1
# 175  EPGt(PB09)_L9      EPGt  EB       1
# 177  EPGt(PB09)_L9      EPGt  EB       1
# 156  EPGt(PB09)_L9      EPGt  EB       1
# 157  EPGt(PB09)_R9      EPGt  EB       1
# 162  EPGt(PB09)_R9      EPGt  EB       1
# 163  EPGt(PB09)_L9      EPGt  EB       1
# 180  EPGt(PB09)_L9      EPGt  EB       1
# 181  EPGt(PB09)_R9      EPGt  EB       1
# 182  EPGt(PB09)_L9      EPGt  EB       1
# 184  EPGt(PB09)_R9      EPGt  EB       1
# 185  EPGt(PB09)_R9      EPGt  EB       1
# 140  EPGt(PB09)_R9      EPGt  EB       1
# 141  EPGt(PB09)_L9      EPGt  EB       1
# 142  EPGt(PB09)_L9      EPGt  EB       1
# 152  EPGt(PB09)_R9      EPGt  EB       1
# 153  EPGt(PB09)_L9      EPGt  EB       1
# 188  EPGt(PB09)_R9      EPGt  EB       1
# 189  EPGt(PB09)_R9      EPGt  EB       1
# 193  EPGt(PB09)_L9      EPGt  EB       1
# 125  EPGt(PB09)_R9      EPGt  PB       1
# 127  EPGt(PB09)_R9      EPGt  PB       1
# 195  EPGt(PB09)_R9      EPGt  EB       1
# 198  EPGt(PB09)_R9      EPGt  EB       1
# 75   EPGt(PB09)_R9      EPGt  EB       1
# 77   EPGt(PB09)_R9      EPGt  EB       1
# 83   EPGt(PB09)_R9      EPGt  PB       1
# 84   EPGt(PB09)_R9      EPGt  EB       1
# 85   EPGt(PB09)_R9      EPGt  EB       1
# 89   EPGt(PB09)_L9      EPGt  EB       1
# 90   EPGt(PB09)_L9      EPGt  EB       1
# 91   EPGt(PB09)_R9      EPGt  PB       1
# 92   EPGt(PB09)_R9      EPGt  PB       1
# 93   EPGt(PB09)_L9      EPGt  EB       1
# 95   EPGt(PB09)_R9      EPGt  PB       1
# 97   EPGt(PB09)_R9      EPGt  EB       1
# 98   EPGt(PB09)_L9      EPGt  EB       1
# 101  EPGt(PB09)_R9      EPGt  EB       1
# 102  EPGt(PB09)_L9      EPGt  EB       1
# 199  EPGt(PB09)_L9      EPGt  EB       1
# 117  EPGt(PB09)_R9      EPGt  EB       1
# 119  EPGt(PB09)_L9      EPGt  EB       1
# 121  EPGt(PB09)_L9      EPGt  EB       1
# 122  EPGt(PB09)_R9      EPGt  PB       1
# 124  EPGt(PB09)_R9      EPGt  EB       1
# 201  EPGt(PB09)_L9      EPGt  EB       1
# 203  EPGt(PB09)_R9      EPGt  EB       1
# 207  EPGt(PB09)_L9      EPGt  EB       1
# 208  EPGt(PB09)_L9      EPGt  EB       1
# 209  EPGt(PB09)_R9      EPGt  EB       1
# 210  EPGt(PB09)_R9      EPGt  EB       1
# 212  EPGt(PB09)_R9      EPGt  EB       1
# 214  EPGt(PB09)_L9      EPGt  EB       1
# 215  EPGt(PB09)_L9      EPGt  EB       1
# 222  EPGt(PB09)_R9      EPGt  EB       1
# 106  EPGt(PB09)_L9      EPGt  PB       1
# 109  EPGt(PB09)_L9      EPGt  PB       1
# 110  EPGt(PB09)_L9      EPGt  EB       1
# 111  EPGt(PB09)_R9      EPGt  EB       1
# 112  EPGt(PB09)_L9      EPGt  EB       1
# 114  EPGt(PB09)_R9      EPGt  EB       1
# 224  EPGt(PB09)_R9      EPGt  EB       1
# 229  EPGt(PB09)_R9      EPGt  EB       1
# 230  EPGt(PB09)_R9      EPGt  EB       1
# 41   EPGt(PB09)_R9      EPGt  PB       1
# 54   EPGt(PB09)_R9      EPGt  EB       1
# 67   EPGt(PB09)_L9      EPGt  EB       1
# 68   EPGt(PB09)_R9      EPGt  EB       1
# 231  EPGt(PB09)_L9      EPGt  EB       1
# 232  EPGt(PB09)_R9      EPGt  EB       1
# 233  EPGt(PB09)_L9      EPGt  EB       1
# 234  EPGt(PB09)_L9      EPGt  EB       1
# 282  EPGt(PB09)_L9      EPGt  EB       1
# 283  EPGt(PB09)_L9      EPGt  EB       1
# 287  EPGt(PB09)_R9      EPGt  EB       1
# 288  EPGt(PB09)_R9      EPGt  EB       1
# 292  EPGt(PB09)_R9      EPGt  PB       1
# 273  EPGt(PB09)_R9      EPGt  EB       1
# 277  EPGt(PB09)_R9      EPGt  EB       1
# 248  EPGt(PB09)_L9      EPGt  EB       1
# 249  EPGt(PB09)_L9      EPGt  EB       1
# 252  EPGt(PB09)_L9      EPGt  PB       1
# 254  EPGt(PB09)_R9      EPGt  EB       1
# 255  EPGt(PB09)_R9      EPGt  EB       1
# 15   EPGt(PB09)_R9      EPGt  EB       1
# 20   EPGt(PB09)_L9      EPGt  PB       1
# 30   EPGt(PB09)_R9      EPGt  PB       1
# 33   EPGt(PB09)_R9      EPGt  PB       1
# 38   EPGt(PB09)_R9      EPGt  PB       1
# 264  EPGt(PB09)_R9      EPGt  EB       1
# 267  EPGt(PB09)_L9      EPGt  EB       1
# 257  EPGt(PB09)_L9      EPGt  EB       1
# 260  EPGt(PB09)_R9      EPGt  PB       1

# %%
cl.visualize_conn(epgt_tot_pre_conn, pre_scale='type', post_scale='type', sort_by='type', weight_col='weight', height=1000, width=300, x_ax_rot=60)
# Out:
# :HeatMap   [columns,index]   (value)

# %%
cl.visualize_conn(epgt_tot_pre_conn, pre_scale='instance', post_scale='instance', sort_by='type', weight_col='weight', height=1200, width=400, x_ax_rot=60)
# Out:
# :HeatMap   [columns,index]   (value)

# %% [markdown]
# ## Main input neuron types:
#
# Delta7 >> PEN_a > PEN_b

# %%
del7_epgt_conn = cl.fetch_connectivity(target_scale='type', conn_scale='type', conn_type='pre', target_id='EPGt', conn_id='Delta7', rois=['EB', 'PB'])

cl.visualize_conn(del7_epgt_conn, pre_scale='instance', post_scale='instance', sort_by='instance', weight_col='weight', height=400, width=300, x_ax_rot=60)
# Out:
# :HeatMap   [columns,index]   (value)

# %%
pena_epgt_conn = cl.fetch_connectivity(target_scale='type', conn_scale='type', conn_type='pre', target_id='EPGt', conn_id='PEN_a(PEN1)', rois=['EB', 'PB'])

cl.visualize_conn(pena_epgt_conn, pre_scale='instance', post_scale='instance', sort_by='instance', weight_col='weight', height=500, width=300, x_ax_rot=60)
# Out:
# :HeatMap   [columns,index]   (value)

# %%
penb_epgt_conn = cl.fetch_connectivity(target_scale='type', conn_scale='type', conn_type='pre', target_id='EPGt', conn_id='PEN_b(PEN2)', rois=['EB', 'PB'])

cl.visualize_conn(penb_epgt_conn, pre_scale='instance', post_scale='instance', sort_by='instance', weight_col='weight', height=400, width=300, x_ax_rot=60)
# Out:
# :HeatMap   [columns,index]   (value)

# %% [markdown]
# ## Downstream targets

# %%
epgt_tot_post_conn = cl.fetch_connectivity(target_scale='type', conn_scale='all', conn_type='post', target_id='EPGt', rois=['EB', 'PB'])

# %%
cl.visualize_conn(epgt_tot_post_conn, pre_scale='type', post_scale='type', sort_by='type', weight_col='weight', height=200, width=1000, x_ax_rot=60)
# Out:
# :HeatMap   [columns,index]   (value)

# %%
cl.visualize_conn(epgt_tot_post_conn, pre_scale='instance', post_scale='instance', sort_by='type', weight_col='weight', height=300, width=1300, x_ax_rot=60)
# Out:
# :HeatMap   [columns,index]   (value)

# %% [markdown]
# ## Main downstream targets:
#
# Delta7 > PEN_b > PEN_a
#
# ### EPGt --> Delta7

# %%
epgt_del7_conn = cl.fetch_connectivity(target_scale='type', conn_scale='type', conn_type='post', target_id='EPGt', conn_id='Delta7', rois=['EB', 'PB'])

cl.visualize_conn(epgt_del7_conn, pre_scale='instance', post_scale='instance', sort_by='instance', weight_col='weight', height=300, width=600, x_ax_rot=60)
# Out:
# :HeatMap   [columns,index]   (value)

# %% [markdown]
# #EPGt --> PEN_b

# %%
epgt_penb_conn = cl.fetch_connectivity(target_scale='type', conn_scale='type', conn_type='post', target_id='EPGt', conn_id='PEN_b(PEN2)', rois=['EB', 'PB'])

cl.visualize_conn(epgt_penb_conn, pre_scale='instance', post_scale='instance', sort_by='instance', weight_col='weight', height=300, width=600, x_ax_rot=60)
# Out:
# :HeatMap   [columns,index]   (value)

# %% [markdown]
# ### PEGt --> PEN_a

# %%
epgt_pena_conn = cl.fetch_connectivity(target_scale='type', conn_scale='type', conn_type='post', target_id='EPGt', conn_id='PEN_a(PEN1)', rois=['EB', 'PB'])

cl.visualize_conn(epgt_pena_conn, pre_scale='instance', post_scale='instance', sort_by='instance', weight_col='weight', height=300, width=600, x_ax_rot=60)
# Out:
# :HeatMap   [columns,index]   (value)
